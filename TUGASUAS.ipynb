# %%
# import modul yang diperlukan
import pandas as pd
import numpy as np

# %%
# baca file dataset csv
df = pd.read_csv('data_mhs.csv')

# %%
## data insight

# %%
# lihat lima data pertama
df.head()
# Out:
#            nim              nama    tahun_akademik  semester_mahasiswa  \
# 0  D1041151001  MUHAMMAD AFFANDI  2019/2020-Ganjil                   9
# 1  D1041151001  MUHAMMAD AFFANDI  2019/2020-Ganjil                   9
# 2  D1041151001  MUHAMMAD AFFANDI  2019/2020-Ganjil                   9
# 3  D1041151001  MUHAMMAD AFFANDI   2019/2020-Genap                  10
# 4  D1041151001  MUHAMMAD AFFANDI  2020/2021-Ganjil                  11
#
#                     nama_mk kelas  sks_matkul  nilai_mutu   ips   ipk
# 0  Tugas Akhir 1 (Proposal)     A           2         4.0  3.33  3.83
# 1            Tugas Akhir 2      A           4         0.0  3.33  3.83
# 2          Pemrograman Web*     A           4         3.0  3.33  3.83
# 3            Tugas Akhir 2      A           4         0.0  0.00  3.83
# 4            Tugas Akhir 2      A           4         0.0  0.00  3.83

# %%
# ambil sampel secara acak dengan jumlah sample 10
df.sample(10)
# Out:
#               nim                            nama    tahun_akademik  \
# 903   D1041161009              ENDAH ARDHIA UTAMI  2020/2021-Ganjil
# 4783  D1041181033                          GUSMAN   2020/2021-Genap
# 102   D1041151024   MARY RUMONDANG ASIMA MANURUNG   2019/2020-Genap
# 3196  D1042171006         GILANG PANGESTU RAMADAN  2019/2020-Ganjil
# 6780  D1041191034        SYAIFUL HILAL FAKHRULLAH  2019/2020-Ganjil
# 7034  D1041191043  MUHAMMAD ALHYMNI RUSSY PRANATA  2019/2020-Ganjil
# 1619  D1042161011                   EDWIN PRADANA   2020/2021-Genap
# 7084  D1041191044         MUHAMMAD LUCKY AL AZHAR   2020/2021-Genap
# 4333  D1041181017                     NURUL FITRI  2020/2021-Ganjil
# 7004  D1041191042               GALUH DWI PRANOTO  2019/2020-Ganjil
#
#       semester_mahasiswa                           nama_mk  kelas  sks_matkul  \
# 903                    9          Tugas Akhir 1 (Proposal)      A           2
# ...

# %%
# lihat jumlah data dan jumlah kolom
df.shape
# Out:
# (8848, 10)

# %%
# lihat nama dari setiap kolom yang ada
df.columns.values
# Out:
# array(['nim', 'nama', 'tahun_akademik', 'semester_mahasiswa', 'nama_mk',
#        'kelas', 'sks_matkul', 'nilai_mutu', 'ips', 'ipk'], dtype=object)

# %%
# lihat tipe data dari setiap kolom
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8848 entries, 0 to 8847
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   nim                 8848 non-null   object
#  1   nama                8848 non-null   object
#  2   tahun_akademik      8848 non-null   object
#  3   semester_mahasiswa  8848 non-null   int64
#  4   nama_mk             8848 non-null   object
#  5   kelas               8848 non-null   object
#  6   sks_matkul          8848 non-null   int64
#  7   nilai_mutu          8848 non-null   float64
#  8   ips                 8848 non-null   float64
#  9   ipk                 8848 non-null   float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 691.4+ KB

# %%
# periksa missing value
df.isnull().sum()
# Out:
# nim                   0
# nama                  0
# tahun_akademik        0
# semester_mahasiswa    0
# nama_mk               0
# kelas                 0
# sks_matkul            0
# nilai_mutu            0
# ips                   0
# ipk                   0
# dtype: int64

# %%
df.drop(['nama', 'nama_mk','kelas'], inplace=True, axis=1)

# %%
df.sample(10)
# Out:
#               nim    tahun_akademik  semester_mahasiswa  sks_matkul  \
# 3764  D1042171040   2019/2020-Genap                   6           3
# 4007  D1041181006  2019/2020-Ganjil                   3           3
# 940   D1041161012   2019/2020-Genap                   8           4
# 5371  D1042181012   2020/2021-Genap                   6           4
# 6829  D1041191035  2020/2021-Ganjil                   3           3
# 1146  D1041161032   2020/2021-Genap                  10           4
# 2106  D1041171006  2019/2020-Ganjil                   5           2
# 6452  D1041191021   2020/2021-Genap                   4           3
# 8740  D1041201060  2020/2021-Ganjil                   1           2
# 1261  D1041161042  2020/2021-Ganjil                   9           4
#
#       nilai_mutu   ips   ipk
# 3764         4.0  3.86  3.73
# 4007         4.0  3.10  3.35
# 940          2.0  2.44  3.43
# 5371         4.0  2.48  2.84
# 6829         3.5  3.25  3.24
# 1146         0.0  0.00  3.56
# ...
